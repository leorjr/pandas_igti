# %%
# pip install pandas
# pip install openpyxl

# %%
import pandas as pd
# Out:
# /home/leonardo/.asdf/installs/python/3.9.6/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
# pd.read_excel?

# %%
# leitura de um arquivo CSV
df = pd.read_csv('https://pycourse.s3.amazonaws.com/temperature.csv')
df.head()

# %%
# leitura de um arquivo excel como um todo pois, possui mais de uma sheet
excel_file = pd.ExcelFile('https://pycourse.s3.amazonaws.com/temperature.xlsx')

# leitura da primeira aba da planilha acima
df2 = pd.read_excel(excel_file, sheet_name="Sheet1")
df2
# Out:
#         date  temperatura classification
# 0 2020-01-01         29.1         quente
# 1 2020-02-01         31.2   muito quente
# 2 2020-03-01         28.5         quente
# 3 2020-04-01         28.0         quente
# 4 2020-05-01         24.0    confortavel
# 5 2020-06-01         20.0           frio
